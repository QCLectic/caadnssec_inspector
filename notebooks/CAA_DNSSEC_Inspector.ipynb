# %% [markdown]
# # CAA DNSSEC Inspector
#
# Thin notebook shell — all logic lives in the `dns_inspector` package.
#
# Run from the repo root so that `dns_inspector/` is on the Python path:
# ```
# jupyter notebook notebooks/CAA_DNSSEC_Inspector.ipynb
# ```

# %%
# Uncomment if dependencies are not yet installed:
# !pip install -r ../requirements.txt

# %%
import sys
import os

# Ensure the repo root is on the path when running from notebooks/
repo_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

from dns_inspector.ui.components import setup_enhanced_ui

# %%
# Launch the DNS checker UI
ui = setup_enhanced_ui()

# %%
# Optional: run caatestsuite.com compliance tests
# from dns_inspector.compliance import run_compliance_tests
# results = run_compliance_tests()
# display(results)
